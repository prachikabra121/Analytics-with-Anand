# %%
print("Hello Welcome to the world of analytics with Analytics with Anand")
# Out:
# Hello Welcome to the world of analytics with Analytics with Anand

# %%
print("Hello Welcome to the world of analytics with Analytics with Anand:)
# Out:
#   Cell In[8], line 1
#     print("Hello Welcome to the world of analytics with Analytics with Anand:)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(7+9)
# Out:
# 16

# %%
print(7+9)
print("Hello Welcome to the world of analytics with Analytics with Anand:)
print("Hello Prachi")
# Out:
#   Cell In[10], line 2
#     print("Hello Welcome to the world of analytics with Analytics with Anand:)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
num1 = 10

# %%
print(num1 + 6)
# Out:
# 16

# %%
print(10+10+56+89+0)
# Out:
# 165

# %%
print(num1)
# Out:
# 10

# %% [markdown]
# <h1>Rules of Variable declaration</h1>
#
# 1)cannot start with number 0-9,can start with _ or char A-Z or a-z
# 2)cannot use specialial char excel _
# 3)cannot contain space in between
# 4)cannot use keywords as a variable name

# %%
1name = 'prachi'
# Out:
#   Cell In[16], line 1
#     1name = 'prachi'
#     ^
# SyntaxError: invalid decimal literal

# %%
first_name = 'prachi'

# %%
first-name ='prachi'
# Out:
#   Cell In[18], line 1
#     first-name ='prachi'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
_fisrt_name ='prachi'

# %%
first name = 'prachi'
# Out:
#   Cell In[20], line 1
#     first name = 'prachi'
#           ^
# SyntaxError: invalid syntax

# %%
#variable example

FirstName = 'Prachi'
firstname ='Prachi'
_firstname ='Prachi'
first_name = 'prachi'
First_Name = 'prachi'
Firstname = 'Prachi'
Firstname10= 'parchi'

# %%
#raise = "prachi"

# %%
ctrl + /
