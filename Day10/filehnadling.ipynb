# %%
file = open("filename","mode")

# %%
f = open("new_data.txt","r")

# %%
f.read()
# Out:
# 'Hello I am Prachi\nI am a data engineer\nI am from Indore'

# %%
f.read()
# Out:
# ''

# %%
f.close()

# %%
f.readline()
# Out:
# 'Hello I am Prachi\n'

# %%
f.readline()
# Out:
# 'I am a data engineer\n'

# %%
f.readline()
# Out:
# 'I am from Indore'

# %%
f.readline()
# Out:
# ''

# %%
f.close()

# %%
l = f.readlines()

# %%
l
# Out:
# ['Hello I am Prachi\n', 'I am a data engineer\n', 'I am from Indore']

# %%
l[1]
# Out:
# 'I am a data engineer\n'

# %%
f.read(10)
# Out:
# 'Hello I am'

# %%
f.read()
# Out:
# ' Prachi\nI am a data engineer\nI am from Indore'

# %%
f = open("new_data.txt","w")

# %%
f.write("Hello Python")
# Out:
# 12

# %%
f.close()

# %%
lines = ["Hello welcome to the world of analytics\n","I am your trainer\n","We are going to learn python together"]

f.writelines(lines)

# %%
f.close()

# %%
with open("new_data.txt","w") as f:
    print(f.write("Today is sunday"))
# Out:
# 15

# %%
with open("new_data.txt","a") as f:
    print(f.write("\nTomorrow will be the Monday"))
# Out:
# 28

# %%
with open("new_data1.txt","x") as f:
    print(f.write("\nTomorrow will be the Monday"))
# Out:
# 28

# %%
with open("image.jpg","rb") as f:
    data=f.read()

# %%
with open("copy.jpg","wb") as f:
    print(f.write(data))
# Out:
# 824874

# %%
image_data = (
    b"BM"                      # Signature
    b"\xF6\x00\x00\x00"        # File size = 246 bytes
    b"\x00\x00"                # Reserved
    b"\x00\x00"                # Reserved
    b"\x36\x00\x00\x00"        # Offset to pixel array (54 bytes)
    b"\x28\x00\x00\x00"        # DIB header size (40 bytes)
    b"\x08\x00\x00\x00"        # Width: 8
    b"\x08\x00\x00\x00"        # Height: 8
    b"\x01\x00"                # Color planes
    b"\x18\x00"                # Bits per pixel: 24
    b"\x00\x00\x00\x00"        # No compression
    b"\xC0\x00\x00\x00"        # Image size (192 bytes)
    b"\x13\x0B\x00\x00"        # Horizontal resolution
    b"\x13\x0B\x00\x00"        # Vertical resolution
    b"\x00\x00\x00\x00"        # Colors in palette
    b"\x00\x00\x00\x00"        # Important colors
    # --- Pixel data: 8×8 pixels (bottom → top), BGR triples ---
    # Row 7
    b"\x00\x00\x00" b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF"
    b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\x00\x00\x00"
    # Row 6
    b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\xFF\xFF\xFF"
    b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\x00\x00\x00"
    # Row 5
    b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF"
    b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\xFF\xFF\xFF"
    # Row 4
    b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\xFF\xFF\xFF"
    b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF"
    # Row 3
    b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00"
    b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF"
    # Row 2
    b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\x00\x00\x00"
    b"\x00\x00\x00" b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF"
    # Row 1
    b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00"
    b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00"
    # Row 0
    b"\x00\x00\x00" b"\x00\x00\x00" b"\xFF\xFF\xFF" b"\xFF\xFF\xFF"
    b"\xFF\xFF\xFF" b"\xFF\xFF\xFF" b"\x00\x00\x00" b"\x00\x00\x00"
)

with open("cat.png","wb") as f:
    print(f.write(image_data))
# Out:
# 246

# %%
import os
os.remove("cat.jpg")

# %%
os.rename("cat.png","Cate_new.png")

# %%
if os.path.exists("Cate_new.png"):
    print("file exists")
else:
    print("File doesnot exists")
# Out:
# file exists

# %%
f = open("new_data.txt","r")

# %%
f.tell()
# Out:
# 0

# %%
f.seek(6)
# Out:
# 6

# %%
f.tell()
# Out:
# 6

# %%
f.read()
# Out:
# 'is sunday\nTomorrow will be the Monday'

# %%
f.read()
# Out:
# ''

# %%
f.seek(2)
# Out:
# 2

# %%
f.tell()
# Out:
# 2

# %%
f.read()
# Out:
# 'day is sunday\nTomorrow will be the Monday'

# %%
data.txt

i love india
i love my country
Today is beautifull day

write a program to count how many lines are present in data.txt

# %%
with open("new_data.txt","r") as f:
    con = f.readlines()
    print(len(con))
# Out:
# 3

# %%
f = open("new_data.txt", "r")
count = 0

for line in f:
    count += 1

print(count)
# Out:
# 3

# %%
count =0
with open("new_data.txt", "r") as file:
    for line in file:
        count += 1
print("Number of lines in data.txt:", count)
# Out:
# Number of lines in data.txt: 3

# %%
count=0
with open ('data.txt','r') as f:
    for line in f:
        count+=1
print(count)

# %%
with open("new_data.txt", "r") as file:
    text=file.read()
    words = text.split()
    print("Number of words:", len(words))
# Out:
# Number of words: 11

# %%
count = 0
in_word = False

with open("new_data.txt", "r") as file:
    text=file.read()
    print(text)
    for i in text:
        if i.isalnum():
            if not in_word:
                count += 1
                in_word = True
        else:
            in_word = False

print(f"total number of words: {count}")
# Out:
# i love india
# i love my country
# Today is beautifull day
# total number of words: 11

# %%
with open("new_data.txt", "r") as file:
    text=file.read()

# %%
text
# Out:
# 'i love india\ni love my country\nToday is beautifull day'

# %%
count = 1
for i in text:
    if i == " " or i == "\n":
        count += 1

print(count)
# Out:
# 11

# %%
Given input.txt, create cleaned.txt by removing empty/blank lines.

# %%
Hello world!

This is a test file.


It contains some blank lines.

Python file handling is easy!


END

# %%
Hello world!
This is a test file.
It contains some blank lines.
Python file handling is easy!
END

# %%
with open("new_data.txt", "r") as file:
    text = file.readlines()
with open("demo2.txt", "w") as t:
    for line in text:
        if line != "\n":      
            t.write(line)

# %%
with open("new_data.txt", "r") as f,open('output.txt','w') as fout:
    for i in f:
        if i != "\n":
            fout.write(i)

# %%
with open("new_data.txt", "r") as fin, open("cleaned.txt", "w") as fout:
    for line in fin:
        if len(line) > 1:   # no strip used
            fout.write(line)
