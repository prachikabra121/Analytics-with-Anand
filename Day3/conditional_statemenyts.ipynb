# %%
age = 18
if age > 18:
    print("Eligigble for the voting")

# %%
age = 18
if age >= 18:
    print("Eligigble for the voting")
# Out:
# Eligigble for the voting

# %%
age = 18
if age > 18:
    print("Eligigble for the voting")
print("bye")
# Out:
# bye

# %%
age = 18
if age >= 18:
    print("Eligigble for the voting")
print("bye")
# Out:
# Eligigble for the voting
# bye

# %%
age = 18
if age > 18:
    print("Eligigble for the voting")

else :
    print("You are not eligible for the voting")
# Out:
# You are not eligible for the voting

# %%
age = 18
if age > 18:
    print("Eligigble for the voting")

else :
    print("You are not eligible for the voting")

print("bye")
# Out:
# You are not eligible for the voting
# bye

# %%
age = 18
if age >= 18:
    print("Eligigble for the voting")

else :
    print("You are not eligible for the voting")

print("bye")
# Out:
# Eligigble for the voting
# bye

# %%
marks = 30
'''if marks are greater than or equals to 85 then grade A, if marks are less than 85 then B+'''
# Out:
# 'if marks are greater than or equals to 85 then grade A, if marks are less than 85 then B+'

# %%
if marks >= 85:
    print("Congo your grade is A")

elif marks <85 and marks>=75:
    print("Congo you achieved B+ grade")

elif marks <75 and marks >=50:
    print("your grade is B")
elif marks <50 and marks >35:
    print("your grade is C")

else:
    print("Regrets")
# Out:
# Regrets

# %%
num1 = 10
num2 = 5

# %%
num1=10
num2=5
a=input("enter ur choice")
if a=="add":
    print(num1+num2)
elif a=="sub":
    print(num1-num2)
elif a=="multiply":
    print(num1*num2)
else:
   print ("enter valid choice")
# Out:
# enter ur choice Add
# enter valid choice

# %%
n1 = 10
n2 = 5
choice = "add"
if choice == "add":
    print(n1+n2)
elif choice == "sub":
    print(n1-n2)
elif choice == "mult":
    print(n * n2)
elif choice == "div":
    print(n1/n2)
elif choice == "exponential":
    print(n ** n2)
elif choice == "modulus":
    print(n % n2)
else:
    print('Invalid')

# %%
num1 = 10
num2 = 5
choice = "-"

if choice == "+":
    print("addition is", num1 + num2)
elif choice == "-":
    print("subtraction is", num1 - num2)
elif choice == "*":
    print("multiplication is", num1 * num2)
elif choice == "/":
    print("quotient is", num1 / num2)
elif choice == "%":
    print("remainder is", num1 % num2)
else:
    print("wrong choice")
# Out:
# subtraction is 5

# %%
#eligibility check for the loan

age = 34
income = 55000

if age>= 18:
    if income >25000:
        print("You are eligible for vthe loan")

    else:
        print("you must earn more than 25000 to eligible for the loan")

else:
    print("your age should be greater than or equals to 18")
# Out:
# You are eligible for vthe loan

# %%
# marks calculator
marks = 100
if marks >= 40:
    print('PASS')
    if marks >= 90:
        print('Grade = O')
    elif marks >= 75 and marks < 90:
        print('Grade = A+')
    elif marks >= 55 and marks < 75:
        print('Grade = B')
    else:
        print('Grade = C')
else:
    print('FAIL')
# Out:
# PASS
# Grade = O

# %%
marks=int(input("enter marks"))
if marks>=40:
    if marks>=90:
        print("outstanding")
    elif marks<90 and marks>=75:
        print("A+")
    elif marks<75 and marks>=55:
        print("B")
    else:
        print("c")
else:
    print("fail")
# Out:
# enter marks 74
# B

# %%
marks = int(input("enter your marks"))

if marks >= 40:
    print("You passed the examination")
    if marks >= 90:
        print("Your Grade is: O")
    elif marks >= 75 and marks <= 80:
        print("Your Grade is: A+")
    elif marks >= 55 and marks <= 75:
        print("Your Grade is: B")
    elif marks >= 40 and marks < 55:
        print("Your Grade is: C")
    else:
        print("Grade: D")
else:
    print("You failed the examination")
# Out:
# enter your marks 54
# You passed the examination
# Your Grade is: C

# %%
mark=95
if mark >= 45:
    print("pass")
    if mark >=95 and mark <= 85:
        print("A+")
    elif mark >= 85 and  mark<= 75:
        print("A")
    elif  mark >= 75 and mark <= 65:
        print("B+")
    elif mark >=65 and mark <= 55:
        print("B")
    elif mark >=55 and mark <40:
        print("c")
else:
    print("not passed")

# %%
num = 11

# %%
result = "Even" if num%2==0 else "odd"
print(result)
# Out:
# odd

# %%
age = 19

votting_eligibility = "person is eligible for voting" if age>=18 else "Not eligible"
print(votting_eligibility)
# Out:
# person is eligible for voting
