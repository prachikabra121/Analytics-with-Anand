# %%
 num1 = 10

# %%
type(num1)
# Out:
# int

# %%
num2 = 20.5
print(type(num2))
# Out:
# <class 'float'>

# %%
num3 = 2+3j

# %%
type(num3)
# Out:
# complex

# %%
x = True

# %%
type(x)
# Out:
# bool

# %%
x="Hello I am Prachi"

# %%
type(x)
# Out:
# str

# %%
x = 9
x= 10
print(x)
# Out:
# 10

# %%
 l = [1,2,'p',True,3.5,2+4j]

# %%
type(l)
# Out:
# list

# %%
 t = (1,2,'p',True,3.5,2+4j)

# %%
type(t)
# Out:
# tuple

# %%
 d = {"Name": "Anand","age": 30}

# %%
type(d)
# Out:
# dict

# %%
s = {1,2,3,3,2}

# %%
type(s)
# Out:
# set

# %%
s
# Out:
# {1, 2, 3}

# %%
type(print("prachi"))
# Out:
# prachi
# NoneType

# %%
result = print("Hello World")
print(result)
# Out:
# Hello World
# None

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
print('3+4')
# Out:
# 3+4

# %%
print(3+4)
# Out:
# 7

# %%
3 + 7 = 11

# %%
print('3 + 7', '=', 3+7)
# Out:
# 3 + 7 = 10

# %%
Greetings = "Hello"
Name = "prachi"
statement = "Whelcome to the world of analytics"

print(Greetings,Name,statement)
# Out:
# Hello prachi Whelcome to the world of analytics

# %%
print(Greetings+Name+statement)
# Out:
# HelloprachiWhelcome to the world of analytics

# %%
print("Hello" +" "+ "prachi" +" "+ "Whelcome to the world of analytics")
# Out:
# Hello prachi Whelcome to the world of analytics

# %%
print('age ', 35, 'name', 'ABC')
# Out:
# age  35 name ABC

# %% [markdown]
# Operators
#
# 1)Arithmatic operators

# %%
num1 = 10
num2 = 5

# %%
num1 + num2
# Out:
# 15

# %%
num1 - num2
# Out:
# 5

# %%
num1 * num2
# Out:
# 50

# %%
num1/num2
# Out:
# 2.0

# %%
10 // 3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
#sales tax
price = 250
tax_rate = 0.18
total = price +(price * tax_rate)

print("Total price after tax: ",total)
# Out:
# Total price after tax:  295.0

# %%
 num1 = 10

# %%
#num1 = num1 + 3
num1 += 3

# %%
num1
# Out:
# 13

# %%
num1 -= 3 #num1 = num1 - 3

# %%
num1
# Out:
# 10

# %%
num1 *= 4

# %%
num1
# Out:
# 28

# %%
num1 /= 7

# %%
num1
# Out:
# 4.0

# %%
num1 //= 3

# %%
num1
# Out:
# 1.0

# %%
num1 = 4

# %%
num1 %= 3

# %%
num1
# Out:
# 1

# %%
total = 0
total += 250

# %%
total
# Out:
# 250

# %%
total += 100

# %%
total
# Out:
# 350

# %%
total -= 75

# %%
total
# Out:
# 275

# %%
 num1 = 5
num2 = 3

# %%
num1 == num2
# Out:
# False

# %%
num1 >num2
# Out:
# True

# %%
num1 != num2
# Out:
# True

# %%
num1 >= num2
# Out:
# True

# %%
num1<= num2
# Out:
# False

# %%
'apple' == "banana"
# Out:
# False

# %%
'apple' == "anana"
# Out:
# False

# %%
zoo > apple

# %%
purchace = 1200
if purchace>1000:
    print("congratulations yopu are eligible for the gift hamper")

else:
    print("better luck next time")
# Out:
# congratulations yopu are eligible for the gift hamper

# %%
5> 3 and 10>5 # True and True
# Out:
# True

# %%
5> 3 and 10>15 # True and False
# Out:
# False

# %%
5> 3 or 10>5 # True or True
# Out:
# True

# %%
5> 3 or 10>15 # True or False
# Out:
# True

# %%
not(5>3) # not True
# Out:
# False

# %%
not(5<3) # not False
# Out:
# True

# %%
x = 10

# %%
type(x)
# Out:
# int

# %%
x = int(input())
# Out:
#  10

# %%
x = 10
y = 10.5

# %%
x+ int(y)
# Out:
# 20

# %%
x= 10
y ='prachi'

# %%
str(x)+y
# Out:
# '10prachi'

# %%
x = 10
y = '10'

# %%
x+int(y)
# Out:
# 20

# %%
x= 10
y ='prachi'

# %%
x+int(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 x+int(y)
#
# ValueError: invalid literal for int() with base 10: 'prachi'

# %%
x = 10
y = 10.5

# %%
x+y
# Out:
# 20.5

# %%
a = 10 # 1010
b = 4   #0100

# %%
a & b   #0000
# Out:
# 0

# %%
a | b #1110
# Out:
# 14

# %%
a ^ b
# Out:
# 14

# %%
a<<1 # 1010 << 1 ---> 00010100 -->20
# Out:
# 20

# %%
a<<2  # 00101000
# Out:
# 40

# %%
a>>1 # 00000101  ----> 5
# Out:
# 5

# %%
a>>2 ## 00000010
# Out:
# 2
